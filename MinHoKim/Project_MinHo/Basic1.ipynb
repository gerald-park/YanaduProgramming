# %%
import pandas as pd
df = pd.read_csv(r'C:\Users\kimmh1\Desktop\2020.03_Data Correlation Analysis in C3\2022.2_Version\ML_Data-Avg-Flank-Flank.csv', encoding = 'euc-kr')
pd.set_option('display.max_columns', 100)
df.head()
# Out:
#    System SN PumpModel  Avg_FF_Axial_LV_set  Avg_FF_Axial_LV_exp  \
# 0  200633191     IPUP2               0.0250             0.071615
# 1  200633197     IPUP2               0.0295             0.071997
# 2  200633655     IPUP2               0.0220             0.076002
# 3  200633659     IPUP2               0.0270             0.074936
# 4  200634530    iXL200               0.0300             0.071223
#
#    Avg_FF_Radial_LV?Rotor_Stator  Avg_FF_Radial_LV?Rotor_Rotor  \
# 0                       0.306974                      0.198576
# 1                       0.304773                      0.219213
# 2                       0.315195                      0.198932
# 3                       0.303663                      0.220583
# 4                       0.300047                      0.255908
#
#    Avg_FF_Radial_LV_6_throughbore  Avg_FF_Axial_6th_set  Avg_FF_Axial_6th_exp  \
# 0                        0.284614              0.039979              0.098647
# ...

# %%
df.to_csv(r'C:\Users\kimmh1\Desktop\2020.03_Data Correlation Analysis in C3\2022.2_Version\test1.csv')

# %%
df.shape
# Out:
# (751, 46)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 751 entries, 0 to 750
# Data columns (total 46 columns):
#  #   Column                                        Non-Null Count  Dtype
# ---  ------                                        --------------  -----
#  0   System SN                                     751 non-null    int64
#  1   PumpModel                                     751 non-null    object
#  2   Avg_FF_Axial_LV_set                           751 non-null    float64
#  3   Avg_FF_Axial_LV_exp                           751 non-null    float64
#  4   Avg_FF_Radial_LV?Rotor_Stator                 751 non-null    float64
#  5   Avg_FF_Radial_LV?Rotor_Rotor                  751 non-null    float64
#  6   Avg_FF_Radial_LV_6_throughbore                751 non-null    float64
#  7   Avg_FF_Axial_6th_set                          751 non-null    float64
#  8   Avg_FF_Axial_6th_exp                          751 non-null    float64
# ...

# %%
df.dtypes
# Out:
# System SN                                         int64
# PumpModel                                        object
# Avg_FF_Axial_LV_set                             float64
# Avg_FF_Axial_LV_exp                             float64
# Avg_FF_Radial_LV?Rotor_Stator                   float64
# Avg_FF_Radial_LV?Rotor_Rotor                    float64
# Avg_FF_Radial_LV_6_throughbore                  float64
# Avg_FF_Axial_6th_set                            float64
# Avg_FF_Axial_6th_exp                            float64
# Avg_FF_Radial_6th_Rotor_Stator                  float64
# Avg_FF_Radial_6th_Rotor_Rotor                   float64
# Avg_FF_Radial_5_6?throughbore                   float64
# Avg_FF_Axial_5th_set                            float64
# Avg_FF_Axial_5th_exp                            float64
# Avg_FF_Radial_5th_Rotor_Stator                  float64
# Avg_FF_Radial_5th_Rotor_Rotor                   float64
# Avg_FF_Radial_4_5?throughbore                   float64
# ...

# %%
df.describe()
# Out:
#           System SN  Avg_FF_Axial_LV_set  Avg_FF_Axial_LV_exp  \
# count  7.510000e+02           751.000000           751.000000
# mean   2.096676e+08             0.026840             0.073987
# std    4.072391e+06             0.001864             0.003962
# min    2.006332e+08             0.021000             0.060954
# 25%    2.100375e+08             0.025500             0.071188
# 50%    2.103393e+08             0.027000             0.073694
# 75%    2.106353e+08             0.028500             0.076610
# max    2.200383e+08             0.030000             0.087927
#
#        Avg_FF_Radial_LV?Rotor_Stator  Avg_FF_Radial_LV?Rotor_Rotor  \
# count                     751.000000                    751.000000
# mean                        0.304960                      0.260752
# std                         0.006983                      0.023067
# min                         0.212007                      0.182068
# 25%                         0.300895                      0.248289
# ...

# %%
df.describe(include='all')
# Out:
#            System SN PumpModel  Avg_FF_Axial_LV_set  Avg_FF_Axial_LV_exp  \
# count   7.510000e+02       751           751.000000           751.000000
# unique           NaN         2                  NaN                  NaN
# top              NaN    iXL200                  NaN                  NaN
# freq             NaN       402                  NaN                  NaN
# mean    2.096676e+08       NaN             0.026840             0.073987
# std     4.072391e+06       NaN             0.001864             0.003962
# min     2.006332e+08       NaN             0.021000             0.060954
# 25%     2.100375e+08       NaN             0.025500             0.071188
# 50%     2.103393e+08       NaN             0.027000             0.073694
# 75%     2.106353e+08       NaN             0.028500             0.076610
# max     2.200383e+08       NaN             0.030000             0.087927
#
#         Avg_FF_Radial_LV?Rotor_Stator  Avg_FF_Radial_LV?Rotor_Rotor  \
# ...
